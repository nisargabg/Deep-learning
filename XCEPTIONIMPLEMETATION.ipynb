# %%
import tensorflow as tf
from tensorflow.keras.layers import Input,Dense,Conv2D,Add
from tensorflow.keras.layers import SeparableConv2D,ReLU
from tensorflow.keras.layers import BatchNormalization,MaxPool2D
from tensorflow.keras.layers import GlobalAvgPool2D
from tensorflow.keras import Model

# %%
# creating the Conv-Batch Norm block

def conv_bn(x, filters, kernel_size, strides=1):
    
    x = Conv2D(filters=filters, 
               kernel_size = kernel_size, 
               strides=strides, 
               padding = 'same', 
               use_bias = False)(x)
    x = BatchNormalization()(x)
    return x

# %%
# creating separableConv-Batch Norm block

def sep_bn(x, filters, kernel_size, strides=1):
    
    x = SeparableConv2D(filters=filters, 
                        kernel_size = kernel_size, 
                        strides=strides, 
                        padding = 'same', 
                        use_bias = False)(x)
    x = BatchNormalization()(x)
    return x

# %%
# entry flow

def entry_flow(x):
    
    x = conv_bn(x, filters =32, kernel_size =3, strides=2)
    x = ReLU()(x)
    x = conv_bn(x, filters =64, kernel_size =3, strides=1)
    tensor = ReLU()(x)
    
    x = sep_bn(tensor, filters = 128, kernel_size =3)
    x = ReLU()(x)
    x = sep_bn(x, filters = 128, kernel_size =3)
    x = MaxPool2D(pool_size=3, strides=2, padding = 'same')(x)
    
    tensor = conv_bn(tensor, filters=128, kernel_size = 1,strides=2)
    x = Add()([tensor,x])
    
    x = ReLU()(x)
    x = sep_bn(x, filters =256, kernel_size=3)
    x = ReLU()(x)
    x = sep_bn(x, filters =256, kernel_size=3)
    x = MaxPool2D(pool_size=3, strides=2, padding = 'same')(x)
    
    tensor = conv_bn(tensor, filters=256, kernel_size = 1,strides=2)
    x = Add()([tensor,x])
    
    x = ReLU()(x)
    x = sep_bn(x, filters =728, kernel_size=3)
    x = ReLU()(x)
    x = sep_bn(x, filters =728, kernel_size=3)
    x = MaxPool2D(pool_size=3, strides=2, padding = 'same')(x)
    
    tensor = conv_bn(tensor, filters=728, kernel_size = 1,strides=2)
    x = Add()([tensor,x])
    return x

# %%
def middle_flow(tensor):
    
    for _ in range(8):
        x = ReLU()(tensor)
        x = sep_bn(x, filters = 728, kernel_size = 3)
        x = ReLU()(x)
        x = sep_bn(x, filters = 728, kernel_size = 3)
        x = ReLU()(x)
        x = sep_bn(x, filters = 728, kernel_size = 3)
        x = ReLU()(x)
        tensor = Add()([tensor,x])
        
    return tensor

# %%
# exit flow

def exit_flow(tensor):
    
    x = ReLU()(tensor)
    x = sep_bn(x, filters = 728,  kernel_size=3)
    x = ReLU()(x)
    x = sep_bn(x, filters = 1024,  kernel_size=3)
    x = MaxPool2D(pool_size = 3, strides = 2, padding ='same')(x)
    
    tensor = conv_bn(tensor, filters =1024, kernel_size=1, strides =2)
    x = Add()([tensor,x])
    
    x = sep_bn(x, filters = 1536,  kernel_size=3)
    x = ReLU()(x)
    x = sep_bn(x, filters = 2048,  kernel_size=3)
    x = GlobalAvgPool2D()(x)
    
    x = Dense (units = 1000, activation = 'softmax')(x)
    
    return x

# %%
# model code

input = Input(shape = (299,299,3))
x = entry_flow(input)
x = middle_flow(x)
output = exit_flow(x)

model = Model (inputs=input, outputs=output)
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  conv2d_29 (Conv2D)             (None, 150, 150, 32  864         ['input_6[0][0]']
#                                 )
#
#  batch_normalization_171 (Batch  (None, 150, 150, 32  128        ['conv2d_29[0][0]']
#  Normalization)                 )
#
#  re_lu_175 (ReLU)               (None, 150, 150, 32  0           ['batch_normalization_171[0][0]']
#                                 )
#
#  conv2d_30 (Conv2D)             (None, 150, 150, 64  18432       ['re_lu_175[0][0]']
#                                 )
#
#  batch_normalization_172 (Batch  (None, 150, 150, 64  256        ['conv2d_30[0][0]']
#  Normalization)                 )
#
#  re_lu_176 (ReLU)               (None, 150, 150, 64  0           ['batch_normalization_172[0][0]']
#                                 )
#
#  separable_conv2d_142 (Separabl  (None, 150, 150, 12  8768       ['re_lu_176[0][0]']
#  eConv2D)                       8)
#
#  batch_normalization_173 (Batch  (None, 150, 150, 12  512        ['separable_conv2d_142[0][0]']
#  Normalization)                 8)
#
#  re_lu_177 (ReLU)               (None, 150, 150, 12  0           ['batch_normalization_173[0][0]']
#                                 8)
#
#  separable_conv2d_143 (Separabl  (None, 150, 150, 12  17536      ['re_lu_177[0][0]']
#  eConv2D)                       8)
#
#  conv2d_31 (Conv2D)             (None, 75, 75, 128)  8192        ['re_lu_176[0][0]']
#
#  batch_normalization_174 (Batch  (None, 150, 150, 12  512        ['separable_conv2d_143[0][0]']
#  Normalization)                 8)
#
#  batch_normalization_175 (Batch  (None, 75, 75, 128)  512        ['conv2d_31[0][0]']
#  Normalization)
#
#  max_pooling2d_19 (MaxPooling2D  (None, 75, 75, 128)  0          ['batch_normalization_174[0][0]']
#  )
#
#  add_51 (Add)                   (None, 75, 75, 128)  0           ['batch_normalization_175[0][0]',
#                                                                   'max_pooling2d_19[0][0]']
#
#  re_lu_178 (ReLU)               (None, 75, 75, 128)  0           ['add_51[0][0]']
#
#  separable_conv2d_144 (Separabl  (None, 75, 75, 256)  33920      ['re_lu_178[0][0]']
#  eConv2D)
#
#  batch_normalization_176 (Batch  (None, 75, 75, 256)  1024       ['separable_conv2d_144[0][0]']
#  Normalization)
#
#  re_lu_179 (ReLU)               (None, 75, 75, 256)  0           ['batch_normalization_176[0][0]']
#
#  separable_conv2d_145 (Separabl  (None, 75, 75, 256)  67840      ['re_lu_179[0][0]']
#  eConv2D)
#
#  conv2d_32 (Conv2D)             (None, 38, 38, 256)  32768       ['batch_normalization_175[0][0]']
#
#  batch_normalization_177 (Batch  (None, 75, 75, 256)  1024       ['separable_conv2d_145[0][0]']
#  Normalization)
#
#  batch_normalization_178 (Batch  (None, 38, 38, 256)  1024       ['conv2d_32[0][0]']
#  Normalization)
#
#  max_pooling2d_20 (MaxPooling2D  (None, 38, 38, 256)  0          ['batch_normalization_177[0][0]']
#  )
#
#  add_52 (Add)                   (None, 38, 38, 256)  0           ['batch_normalization_178[0][0]',
#                                                                   'max_pooling2d_20[0][0]']
#
#  re_lu_180 (ReLU)               (None, 38, 38, 256)  0           ['add_52[0][0]']
#
#  separable_conv2d_146 (Separabl  (None, 38, 38, 728)  188672     ['re_lu_180[0][0]']
#  eConv2D)
#
#  batch_normalization_179 (Batch  (None, 38, 38, 728)  2912       ['separable_conv2d_146[0][0]']
#  Normalization)
#
#  re_lu_181 (ReLU)               (None, 38, 38, 728)  0           ['batch_normalization_179[0][0]']
#
#  separable_conv2d_147 (Separabl  (None, 38, 38, 728)  536536     ['re_lu_181[0][0]']
#  eConv2D)
#
#  conv2d_33 (Conv2D)             (None, 19, 19, 728)  186368      ['batch_normalization_178[0][0]']
#
#  batch_normalization_180 (Batch  (None, 38, 38, 728)  2912       ['separable_conv2d_147[0][0]']
#  Normalization)
#
#  batch_normalization_181 (Batch  (None, 19, 19, 728)  2912       ['conv2d_33[0][0]']
#  Normalization)
#
#  max_pooling2d_21 (MaxPooling2D  (None, 19, 19, 728)  0          ['batch_normalization_180[0][0]']
#  )
#
#  add_53 (Add)                   (None, 19, 19, 728)  0           ['batch_normalization_181[0][0]',
#                                                                   'max_pooling2d_21[0][0]']
#
#  re_lu_182 (ReLU)               (None, 19, 19, 728)  0           ['add_53[0][0]']
#
#  separable_conv2d_148 (Separabl  (None, 19, 19, 728)  536536     ['re_lu_182[0][0]']
#  eConv2D)
#
#  batch_normalization_182 (Batch  (None, 19, 19, 728)  2912       ['separable_conv2d_148[0][0]']
#  Normalization)
#
#  re_lu_183 (ReLU)               (None, 19, 19, 728)  0           ['batch_normalization_182[0][0]']
#
#  separable_conv2d_149 (Separabl  (None, 19, 19, 728)  536536     ['re_lu_183[0][0]']
#  eConv2D)
#
#  batch_normalization_183 (Batch  (None, 19, 19, 728)  2912       ['separable_conv2d_149[0][0]']
#  Normalization)
#
#  re_lu_184 (ReLU)               (None, 19, 19, 728)  0           ['batch_normalization_183[0][0]']
#
#  separable_conv2d_150 (Separabl  (None, 19, 19, 728)  536536     ['re_lu_184[0][0]']
#  eConv2D)
#
#  batch_normalization_184 (Batch  (None, 19, 19, 728)  2912       ['separable_conv2d_150[0][0]']
#  Normalization)
#
#  re_lu_185 (ReLU)               (None, 19, 19, 728)  0           ['batch_normalization_184[0][0]']
#
#  add_54 (Add)                   (None, 19, 19, 728)  0           ['add_53[0][0]',
#                                                                   're_lu_185[0][0]']
#
#  re_lu_186 (ReLU)               (None, 19, 19, 728)  0           ['add_54[0][0]']
#
#  separable_conv2d_151 (Separabl  (None, 19, 19, 728)  536536     ['re_lu_186[0][0]']
#  eConv2D)
#
#  batch_normalization_185 (Batch  (None, 19, 19, 728)  2912       ['separable_conv2d_151[0][0]']
#  Normalization)
#
#  re_lu_187 (ReLU)               (None, 19, 19, 728)  0           ['batch_normalization_185[0][0]']
#
#  separable_conv2d_152 (Separabl  (None, 19, 19, 728)  536536     ['re_lu_187[0][0]']
#  eConv2D)
#
#  batch_normalization_186 (Batch  (None, 19, 19, 728)  2912       ['separable_conv2d_152[0][0]']
#  Normalization)
#
#  re_lu_188 (ReLU)               (None, 19, 19, 728)  0           ['batch_normalization_186[0][0]']
#
#  separable_conv2d_153 (Separabl  (None, 19, 19, 728)  536536     ['re_lu_188[0][0]']
#  eConv2D)
#
#  batch_normalization_187 (Batch  (None, 19, 19, 728)  2912       ['separable_conv2d_153[0][0]']
#  Normalization)
#
#  re_lu_189 (ReLU)               (None, 19, 19, 728)  0           ['batch_normalization_187[0][0]']
#
#  add_55 (Add)                   (None, 19, 19, 728)  0           ['add_54[0][0]',
#                                                                   're_lu_189[0][0]']
#
#  re_lu_190 (ReLU)               (None, 19, 19, 728)  0           ['add_55[0][0]']
#
#  separable_conv2d_154 (Separabl  (None, 19, 19, 728)  536536     ['re_lu_190[0][0]']
#  eConv2D)
#
#  batch_normalization_188 (Batch  (None, 19, 19, 728)  2912       ['separable_conv2d_154[0][0]']
#  Normalization)
#
#  re_lu_191 (ReLU)               (None, 19, 19, 728)  0           ['batch_normalization_188[0][0]']
#
#  separable_conv2d_155 (Separabl  (None, 19, 19, 728)  536536     ['re_lu_191[0][0]']
#  eConv2D)
#
#  batch_normalization_189 (Batch  (None, 19, 19, 728)  2912       ['separable_conv2d_155[0][0]']
#  Normalization)
#
#  re_lu_192 (ReLU)               (None, 19, 19, 728)  0           ['batch_normalization_189[0][0]']
#
#  separable_conv2d_156 (Separabl  (None, 19, 19, 728)  536536     ['re_lu_192[0][0]']
#  eConv2D)
#
#  batch_normalization_190 (Batch  (None, 19, 19, 728)  2912       ['separable_conv2d_156[0][0]']
#  Normalization)
#
#  re_lu_193 (ReLU)               (None, 19, 19, 728)  0           ['batch_normalization_190[0][0]']
#
#  add_56 (Add)                   (None, 19, 19, 728)  0           ['add_55[0][0]',
#                                                                   're_lu_193[0][0]']
#
#  re_lu_194 (ReLU)               (None, 19, 19, 728)  0           ['add_56[0][0]']
#
#  separable_conv2d_157 (Separabl  (None, 19, 19, 728)  536536     ['re_lu_194[0][0]']
#  eConv2D)
#
#  batch_normalization_191 (Batch  (None, 19, 19, 728)  2912       ['separable_conv2d_157[0][0]']
#  Normalization)
#
#  re_lu_195 (ReLU)               (None, 19, 19, 728)  0           ['batch_normalization_191[0][0]']
#
#  separable_conv2d_158 (Separabl  (None, 19, 19, 728)  536536     ['re_lu_195[0][0]']
#  eConv2D)
#
#  batch_normalization_192 (Batch  (None, 19, 19, 728)  2912       ['separable_conv2d_158[0][0]']
#  Normalization)
#
#  re_lu_196 (ReLU)               (None, 19, 19, 728)  0           ['batch_normalization_192[0][0]']
#
#  separable_conv2d_159 (Separabl  (None, 19, 19, 728)  536536     ['re_lu_196[0][0]']
#  eConv2D)
#
#  batch_normalization_193 (Batch  (None, 19, 19, 728)  2912       ['separable_conv2d_159[0][0]']
#  Normalization)
#
#  re_lu_197 (ReLU)               (None, 19, 19, 728)  0           ['batch_normalization_193[0][0]']
#
#  add_57 (Add)                   (None, 19, 19, 728)  0           ['add_56[0][0]',
#                                                                   're_lu_197[0][0]']
#
#  re_lu_198 (ReLU)               (None, 19, 19, 728)  0           ['add_57[0][0]']
#
#  separable_conv2d_160 (Separabl  (None, 19, 19, 728)  536536     ['re_lu_198[0][0]']
#  eConv2D)
#
#  batch_normalization_194 (Batch  (None, 19, 19, 728)  2912       ['separable_conv2d_160[0][0]']
#  Normalization)
#
#  re_lu_199 (ReLU)               (None, 19, 19, 728)  0           ['batch_normalization_194[0][0]']
#
#  separable_conv2d_161 (Separabl  (None, 19, 19, 728)  536536     ['re_lu_199[0][0]']
#  eConv2D)
#
#  batch_normalization_195 (Batch  (None, 19, 19, 728)  2912       ['separable_conv2d_161[0][0]']
#  Normalization)
#
#  re_lu_200 (ReLU)               (None, 19, 19, 728)  0           ['batch_normalization_195[0][0]']
#
#  separable_conv2d_162 (Separabl  (None, 19, 19, 728)  536536     ['re_lu_200[0][0]']
#  eConv2D)
#
#  batch_normalization_196 (Batch  (None, 19, 19, 728)  2912       ['separable_conv2d_162[0][0]']
#  Normalization)
#
#  re_lu_201 (ReLU)               (None, 19, 19, 728)  0           ['batch_normalization_196[0][0]']
#
#  add_58 (Add)                   (None, 19, 19, 728)  0           ['add_57[0][0]',
#                                                                   're_lu_201[0][0]']
#
#  re_lu_202 (ReLU)               (None, 19, 19, 728)  0           ['add_58[0][0]']
#
#  separable_conv2d_163 (Separabl  (None, 19, 19, 728)  536536     ['re_lu_202[0][0]']
#  eConv2D)
#
#  batch_normalization_197 (Batch  (None, 19, 19, 728)  2912       ['separable_conv2d_163[0][0]']
#  Normalization)
#
#  re_lu_203 (ReLU)               (None, 19, 19, 728)  0           ['batch_normalization_197[0][0]']
#
#  separable_conv2d_164 (Separabl  (None, 19, 19, 728)  536536     ['re_lu_203[0][0]']
#  eConv2D)
#
#  batch_normalization_198 (Batch  (None, 19, 19, 728)  2912       ['separable_conv2d_164[0][0]']
#  Normalization)
#
#  re_lu_204 (ReLU)               (None, 19, 19, 728)  0           ['batch_normalization_198[0][0]']
#
#  separable_conv2d_165 (Separabl  (None, 19, 19, 728)  536536     ['re_lu_204[0][0]']
#  eConv2D)
#
#  batch_normalization_199 (Batch  (None, 19, 19, 728)  2912       ['separable_conv2d_165[0][0]']
#  Normalization)
#
#  re_lu_205 (ReLU)               (None, 19, 19, 728)  0           ['batch_normalization_199[0][0]']
#
#  add_59 (Add)                   (None, 19, 19, 728)  0           ['add_58[0][0]',
#                                                                   're_lu_205[0][0]']
#
#  re_lu_206 (ReLU)               (None, 19, 19, 728)  0           ['add_59[0][0]']
#
#  separable_conv2d_166 (Separabl  (None, 19, 19, 728)  536536     ['re_lu_206[0][0]']
#  eConv2D)
#
#  batch_normalization_200 (Batch  (None, 19, 19, 728)  2912       ['separable_conv2d_166[0][0]']
#  Normalization)
#
#  re_lu_207 (ReLU)               (None, 19, 19, 728)  0           ['batch_normalization_200[0][0]']
#
#  separable_conv2d_167 (Separabl  (None, 19, 19, 728)  536536     ['re_lu_207[0][0]']
#  eConv2D)
#
#  batch_normalization_201 (Batch  (None, 19, 19, 728)  2912       ['separable_conv2d_167[0][0]']
#  Normalization)
#
#  re_lu_208 (ReLU)               (None, 19, 19, 728)  0           ['batch_normalization_201[0][0]']
#
#  separable_conv2d_168 (Separabl  (None, 19, 19, 728)  536536     ['re_lu_208[0][0]']
#  eConv2D)
#
#  batch_normalization_202 (Batch  (None, 19, 19, 728)  2912       ['separable_conv2d_168[0][0]']
#  Normalization)
#
#  re_lu_209 (ReLU)               (None, 19, 19, 728)  0           ['batch_normalization_202[0][0]']
#
#  add_60 (Add)                   (None, 19, 19, 728)  0           ['add_59[0][0]',
#                                                                   're_lu_209[0][0]']
#
#  re_lu_210 (ReLU)               (None, 19, 19, 728)  0           ['add_60[0][0]']
#
#  separable_conv2d_169 (Separabl  (None, 19, 19, 728)  536536     ['re_lu_210[0][0]']
#  eConv2D)
#
#  batch_normalization_203 (Batch  (None, 19, 19, 728)  2912       ['separable_conv2d_169[0][0]']
#  Normalization)
#
#  re_lu_211 (ReLU)               (None, 19, 19, 728)  0           ['batch_normalization_203[0][0]']
#
#  separable_conv2d_170 (Separabl  (None, 19, 19, 728)  536536     ['re_lu_211[0][0]']
#  eConv2D)
#
#  batch_normalization_204 (Batch  (None, 19, 19, 728)  2912       ['separable_conv2d_170[0][0]']
#  Normalization)
#
#  re_lu_212 (ReLU)               (None, 19, 19, 728)  0           ['batch_normalization_204[0][0]']
#
#  separable_conv2d_171 (Separabl  (None, 19, 19, 728)  536536     ['re_lu_212[0][0]']
#  eConv2D)
#
#  batch_normalization_205 (Batch  (None, 19, 19, 728)  2912       ['separable_conv2d_171[0][0]']
#  Normalization)
#
#  re_lu_213 (ReLU)               (None, 19, 19, 728)  0           ['batch_normalization_205[0][0]']
#
#  add_61 (Add)                   (None, 19, 19, 728)  0           ['add_60[0][0]',
#                                                                   're_lu_213[0][0]']
#
#  re_lu_214 (ReLU)               (None, 19, 19, 728)  0           ['add_61[0][0]']
#
#  separable_conv2d_172 (Separabl  (None, 19, 19, 728)  536536     ['re_lu_214[0][0]']
#  eConv2D)
#
#  batch_normalization_206 (Batch  (None, 19, 19, 728)  2912       ['separable_conv2d_172[0][0]']
#  Normalization)
#
#  re_lu_215 (ReLU)               (None, 19, 19, 728)  0           ['batch_normalization_206[0][0]']
#
#  separable_conv2d_173 (Separabl  (None, 19, 19, 1024  752024     ['re_lu_215[0][0]']
#  eConv2D)                       )
#
#  conv2d_34 (Conv2D)             (None, 10, 10, 1024  745472      ['add_61[0][0]']
#                                 )
#
#  batch_normalization_207 (Batch  (None, 19, 19, 1024  4096       ['separable_conv2d_173[0][0]']
#  Normalization)                 )
#
#  batch_normalization_208 (Batch  (None, 10, 10, 1024  4096       ['conv2d_34[0][0]']
#  Normalization)                 )
#
#  max_pooling2d_22 (MaxPooling2D  (None, 10, 10, 1024  0          ['batch_normalization_207[0][0]']
#  )                              )
#
#  add_62 (Add)                   (None, 10, 10, 1024  0           ['batch_normalization_208[0][0]',
#                                 )                                 'max_pooling2d_22[0][0]']
#
#  separable_conv2d_174 (Separabl  (None, 10, 10, 1536  1582080    ['add_62[0][0]']
#  eConv2D)                       )
#
#  batch_normalization_209 (Batch  (None, 10, 10, 1536  6144       ['separable_conv2d_174[0][0]']
#  Normalization)                 )
#
#  re_lu_216 (ReLU)               (None, 10, 10, 1536  0           ['batch_normalization_209[0][0]']
#                                 )
#
#  separable_conv2d_175 (Separabl  (None, 10, 10, 2048  3159552    ['re_lu_216[0][0]']
#  eConv2D)                       )
#
#  batch_normalization_210 (Batch  (None, 10, 10, 2048  8192       ['separable_conv2d_175[0][0]']
#  Normalization)                 )
#
#  global_average_pooling2d_4 (Gl  (None, 2048)        0           ['batch_normalization_210[0][0]']
#  obalAveragePooling2D)
#
#  dense_4 (Dense)                (None, 1000)         2049000     ['global_average_pooling2d_4[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 22,910,480
# Trainable params: 22,855,952
# Non-trainable params: 54,528
# __________________________________________________________________________________________________

# %%
import numpy as np 
import tensorflow.keras.backend as K 
np.sum([K.count_params(p) for p in model.trainable_weights])
# Out:
# 22855952
